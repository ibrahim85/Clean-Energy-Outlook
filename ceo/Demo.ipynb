# %% [markdown]
# Importing datacleaning module

# %%
import datacleaning as dc

# %%
dc.clean_all_data()
# Out:
# C:\Users\rahul\Desktop\Clean-Energy-Outlook\Clean_Energy_Outlook\datacleaning.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dftemp['CLPRB'][i-1] = table.row_values(i)[3] # columns 4

# %%
a=[1,2,3]

# %%
a
# Out:
# [1, 2, 3]

# %%
b=[2,3,4]

# %%
all([any(2 == i for i in a),any(3 == i for i in b)])
# Out:
# True

# %%
import numpy

# %%
import pandas as pd

# %%
az=pd.DataFrame([[1,2,3],[4,5,6]],columns=['a','b','c'])

# %%
all([any('a' == i for i in az.columns),any('b' == i for i in az.columns)])
# Out:
# True

# %%
pd.read_csv("Data/Cleaned Data/AK.csv")
# Out:
#     Year   HYTCP  WYTCP  SOEGP  NUETP         NGMPB    PCP  Nominal Price  \
# 0   1960   290.0    0.0    0.0    0.0     248.33801  37.81           2.91
# 1   1961   297.0    0.0    0.0    0.0     636.99709  41.09           2.85
# 2   1962   304.0    0.0    0.0    0.0    2204.75697  35.39           2.85
# 3   1963   325.0    0.0    0.0    0.0    4540.74947  39.96           2.91
# 4   1964   322.0    0.0    0.0    0.0    6331.60975  35.71           3.00
# 5   1965   350.0    0.0    0.0    0.0    7323.95229  38.04           3.01
# 6   1966   316.0    0.0    0.0    0.0   11374.08276  33.79           3.10
# 7   1967   363.0    0.0    0.0    0.0   14575.22028  39.07           3.12
# 8   1968   364.0    0.0    0.0    0.0   17507.82971  29.43           3.18
# 9   1969   341.0    0.0    0.0    0.0   51347.41686  29.44           3.32
# 10  1970   363.0    0.0    0.0    0.0  112636.43015  36.26           3.39
# 11  1971   363.0    0.0    0.0    0.0  122427.39282  36.28           3.60
# ...

# %%
a=['a','d','b']

# %%
import datacleaning as dc

# %%
dc.clean_all_data()

# %%
b=['d','a','b']

# %%
all(numpy.sort(a) == numpy.sort(b))
# Out:
# True

# %% [markdown]
# The CSV files of the states are stored in the Data/Cleaned Data folder
